# %%
import pandas as pd
import pickle
import numpy as np
import json
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
import timeit

# %%
df = pd.read_csv('data/accident.csv')

# %%
fig, ax = plt.subplots(figsize = (8, 10))
df.plot(ax = ax, alpha = 0.4, color = 'grey')
df[(df['month'] == 12) & (df['day']== 31)].plot(ax = ax, markersize =20, color = 'red', marker = 'o', label = 'Collision')

# %%
acc.groupby('SEVERITYDESC')['SEVERITYDESC'].count().plot(kind= 'bar')

# %%
acc.groupby('SEVERITYDESC')['SEVERITYDESC'].count()
# Out:
# SEVERITYDESC
# Fatality Collision                   99
# Injury Collision                  20629
# Property Damage Only Collision    46630
# Serious Injury Collision           1055
# Name: SEVERITYDESC, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (8, 10))
acc.plot(ax = ax, alpha = 0.4, color = 'grey')
acc[acc['SEVERITYDESC']=='Fatality Collision'].plot(ax = ax, markersize =30, color = 'red', marker = 'o', label = 'Collision')
acc[acc['SEVERITYDESC']=='Property Damage Only Collision'].plot(ax = ax, markersize = .1, color = 'green', marker = 'o')

# %%
label = LabelEncoder()
label.fit(acc['SEVERITYDESC'])
acc.loc[:, 'SEVERITYDESC'] = label.transform(acc['SEVERITYDESC'])
# Out:
# /Users/gulomjon/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
acc.loc[:, 'WEATHER'] = label.transform(acc['WEATHER'])
acc.loc[:, 'ROADCOND'] = label.transform(acc['ROADCOND'])
acc.loc[:, 'LIGHTCOND'] = label.transform(acc['LIGHTCOND'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in _encode_python(values, uniques, encode)
#      67         try:
# ---> 68             encoded = np.array([table[v] for v in values])
#      69         except KeyError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in <listcomp>(.0)
#      67         try:
# ---> 68             encoded = np.array([table[v] for v in values])
#      69         except KeyError as e:
#
# KeyError: 'Snowing'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-487-f9a974140a3c> in <module>
# ----> 1 acc.loc[:, 'WEATHER'] = label.transform(acc['WEATHER'])
#       2 acc.loc[:, 'ROADCOND'] = label.transform(acc['ROADCOND'])
#       3 acc.loc[:, 'LIGHTCOND'] = label.transform(acc['LIGHTCOND'])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in transform(self, y)
#     255             return np.array([])
#     256
# --> 257         _, y = _encode(y, uniques=self.classes_, encode=True)
#     258         return y
#     259
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in _encode(values, uniques, encode)
#     106     """
#     107     if values.dtype == object:
# --> 108         return _encode_python(values, uniques, encode)
#     109     else:
#     110         return _encode_numpy(values, uniques, encode)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py in _encode_python(values, uniques, encode)
#      69         except KeyError as e:
#      70             raise ValueError("y contains previously unseen labels: %s"
# ---> 71                              % str(e))
#      72         return uniques, encoded
#      73     else:
#
# ValueError: y contains previously unseen labels: 'Snowing'

# %%
for i in X:
    if X[i].dtype == 'object':
        label.fit(X[i])
        X.loc[:, i] = label.transform(X[i])
# Out:
# /Users/gulomjon/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68413 entries, 4093 to 199841
# Data columns (total 4 columns):
# WEATHER      68413 non-null int64
# ROADCOND     68413 non-null int64
# LIGHTCOND    68413 non-null int64
# AAWDT        68413 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 2.6 MB

# %%
X = acc['AAWDT']
# Out:
# (68413,)

# %%
y.shape
# Out:
# (68413,)

# %%
X_train = X[:28804]
y_train = y[:28804]
X_test = X[28804:]
y_test = y[28804:]

# %%
from sklearn.ensemble import RandomForestClassifier
m = RandomForestClassifier(n_estimators=50, criterion='entropy')
m.fit(X_train.values.reshape(-1,1), y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print('train score of acuracy', m.score(X_train.values.reshape(-1,1), y_train))
print('test score of accuracy ', m.score(X_test.values.reshape(-1,1), y_test))
# Out:
# train score of acuracy 0.7053534231356756
# test score of accuracy  0.6590926304627737

# %%
y_ran = np.random.randint(0, 5, size = 39609)

# %%
print('random prediction accuracy', m.score(X_test.values.reshape(-1,1), y_ran))
# Out:
# random prediction accuracy 0.19997980257012296

# %%
y_pred = m.predict(X_test.values.reshape(-1,1))

# %%
from sklearn.metrics import precision_score, recall_score

# %%
precision_score(y_test, y_pred, average='micro')
# Out:
# 0.6590926304627737

# %%
recall_score(y_test, y_pred, average='micro')
# Out:
# 0.6590926304627737

# %%
ind
# Out:
# array([   1,    2, 1583, 1594, 1595, 1852])

# %%
fig, ax = plt.subplots(figsize = (16, 10))
acc.plot(ax = ax, alpha = 0.4, color = 'grey')
vol_2016[vol_2016['DOWNTOWN']=='N'].plot(ax = ax, markersize =70, color = 'red')
